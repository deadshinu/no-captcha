# %% [markdown]
# <a href="https://colab.research.google.com/github/deadshinu/no-captcha/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !zip qtwebengine.zip -r qtwebengine
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/global-handles.cc (deflated 78%)
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/handles.h (deflated 67%)
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/local-handles.cc (deflated 67%)
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/handles-inl.h (deflated 72%)
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/persistent-handles.h (deflated 64%)
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/handles.cc (deflated 65%)
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/OWNERS (deflated 39%)
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/global-handles.h (deflated 69%)
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/maybe-handles-inl.h (deflated 79%)
#   adding: qtwebengine/src/3rdparty/chromium/v8/src/handles/local-handles-inl.h (deflated 67%)
# ...
